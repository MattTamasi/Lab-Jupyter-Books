# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import HTML
from IPython.core.display import Image, display

# %% [markdown]
# # Lipase Experimentation Notebook:

# %% [markdown]
# ![Lipase%20Picture.jpg](attachment:Lipase%20Picture.jpg)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Lipase Information:</b>
# <br> Source: Pseudomonas Cepacia
# <br> Molecular Weight: 33190.84 Daltons
# <br><b> Sequence Info: http://www.rcsb.org/pdb/explore/remediatedSequence.do?structureId=3LIP</b>
# </div>
#
#
# <div class="alert alert-block alert-success">
#
# <b> Proposed Stability:</b>
# </div>
#
# ![Activity1.png](attachment:Activity1.png)

# %% [markdown]
# ## Experiments:

# %% [markdown]
# #### Experiment 1 (6/25/19)
# First testing with polymers. Lipase was held at room temperature while polymers (#114 - #120) were added. Lipase was made at a stock concentration of 0.8 mg/ml and polymers were diluted by adding 3uL of stock solution to 297uL of phosphate buffer.
#
# Note: These polymers are constructed of `MMA-PEGMA-HPMA-DMAPMA (+)`

# %%
data = pd.read_excel(r'C:\Users\Matt Tamasi\Desktop\Python Codes\Lipase Trial.xlsx')

# %%
plt.figure(figsize=(12, 6))
ax = sns.pointplot('Charge', 'Absorbance', hue = 'Exp',
    data=data, dodge=True, join=False,palette = 'Set2')
text = ax.set_title('Lipase Activity vs Cationic Charge')

# %% [markdown]
# #### Experiment 2 (6/27/19)
# Lipase was held at room temperature while polymers (#81 - #88) were added. Lipase was made at a stock concentration of 0.8 mg/ml and polymers were diluted by adding 3uL of stock solution to 297uL of phosphate buffer.
#
# Note: These polymers are constructed of `MMA-PEGMA-HPMA-SPMA (-)`

# %%
data2 = pd.read_excel(r'C:\Users\Matt Tamasi\Desktop\Python Codes\Lipase Trial2.xlsx')
plt.figure(figsize=(12, 6))

ax = sns.pointplot('Charge', 'Absorbance', hue = 'Exp',
    data=data2, dodge=True, join=False,palette = 'Set2')
text = ax.set_title('Lipase Activity vs Anionic Charge')

# %% [markdown]
# #### Experiment 3 (6/27/19)
# Lipase was held at room temperature while polymers (#89 - #96) were added. Lipase was made at a stock concentration of 0.8 mg/ml and polymers were diluted by adding 3uL of stock solution to 297uL of phosphate buffer.
#
# Note: These polymers are constructed of `MMA-PEGMA-HPMA-SPMA (-)`

# %%
Data = {'Polymer':['Positive Ctrl','Positive Ctrl','Positive Ctrl','Negative Ctrl','Negative Ctrl','Negative Ctrl',89,89,89,90,90,90,91,91,91,92,92,92,93,93,93,94,94,94,95,95,95,96,96,96],'Absorbance':[1.399,1.362,1.472,.301,.285,.295,1.366,1.324,1.258,1.202,1.183,1.205,1.238,1.202,1.302,1.210,1.301,1.244,1.384,1.276,1.298,1.318,1.271,1.212,1.277,1.373,1.254,1.172,1.365,1.352]}

A1 = [89,89,89,90,90,90,91,91,91,92,92,92,93,93,93,94,94,94,95,95,95,96,96,96]
A2 = [1.366,1.324,1.258,1.202,1.183,1.205,1.238,1.202,1.302,1.210,1.301,1.244,1.384,1.276,1.298,1.318,1.271,1.212,1.277,1.373,1.254,1.172,1.365,1.352]

DF = pd.DataFrame(data = Data)
plt.figure(figsize=(12, 6))

ax = sns.barplot('Polymer', 'Absorbance',
    data=DF,palette = 'Set2')
text = ax.set_title('Lipase Activity vs Anionic Polymers')

# %%
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.
